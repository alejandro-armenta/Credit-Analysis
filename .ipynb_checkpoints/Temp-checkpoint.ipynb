# %%
import pandas as pd

# %%
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#no categorico
df['LIMIT_BAL']
# Out:
# 0         20000
# 1        120000
# 2         90000
# 3         50000
# 4         50000
#           ...
# 29995    220000
# 29996    150000
# 29997     30000
# 29998     80000
# 29999     50000
# Name: LIMIT_BAL, Length: 30000, dtype: int64

# %%
#categorico
df['SEX'].unique()
# Out:
# array([2, 1, 0])

# %%
#decide credit worthiness
#categorico
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 0, 4, 6])

# %%
#categorico
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
#no categorico
df['AGE'].unique()
# Out:
# array([24, 26, 34, 37, 57, 29, 23, 28, 35, 51, 41, 30, 49, 39, 40, 27, 47,
#        33, 32, 54, 58, 22, 25, 31, 46, 42, 43, 45, 56, 44, 53, 38, 63, 36,
#        52, 48, 55, 60, 50,  0, 75, 61, 73, 59, 21, 67, 66, 62, 70, 72, 64,
#        65, 71, 69, 68, 79, 74])

# %%
#repayment status
#payment delay in 5 months
#categorizado
df['PAY_1'].unique()
# Out:
# array([2, -1, 0, -2, 1, 'Not available', 3, 4, 8, 7, 5, 6], dtype=object)

# %%
df['PAY_2'].unique()
# Out:
# array([ 2,  0, -1, -2,  3,  5,  7,  4,  1,  6,  8])

# %%
#cuanto se pago?
df['BILL_AMT1'].unique()
# Out:
# array([ 3913,  2682, 29239, ...,  1683, -1645, 47929])

# %%
df['PAY_AMT1'].unique()
# Out:
# array([    0,  1518,  2000, ..., 10029,  9054, 85900])

# %%
df
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57    -1      0
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29995  ecff42d0-bdc6     220000    1          3         1   39     0      0
# 29996  99d1fa0e-222b     150000    1          3         2   43    -1     -1
# 29997  95cdd3e7-4f24      30000    1          2         2   37     4      3
# 29998  00d03f02-04cd      80000    1          3         1   41     1     -1
# 29999  15d69f9f-5ad3      50000    1          2         1   46     0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1     -1  ...          0          0          0         0       689
# 1          0      0  ...       3272       3455       3261         0      1000
# 2          0      0  ...      14331      14948      15549      1518      1500
# 3          0      0  ...      28314      28959      29547      2000      2019
# 4         -1      0  ...      20940      19146      19131      2000     36681
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29995      0      0  ...      88004      31237      15980      8500     20000
# 29996     -1     -1  ...       8979       5190          0      1837      3526
# 29997      2     -1  ...      20878      20582      19357         0         0
# 29998      0      0  ...      52774      11855      48944     85900      3409
# 29999      0      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
isUnique = df['ID'].nunique() == 30000
isUnique
# Out:
# False

# %%
id_counts = df['ID'].value_counts()
dupe_mask = id_counts == 2
dupe_mask
# Out:
# 3511ed92-c434     True
# 8a6bbf3d-8a2d     True
# a51dbaae-d88b     True
# b74033dc-6e45     True
# 8567249b-827e     True
#                  ...
# d4ad69e5-537f    False
# 624c4b40-0ff8    False
# 673e9398-0429    False
# 910f87f4-9a63    False
# 57dce644-7002    False
# Name: ID, Length: 29687, dtype: bool

# %%
dupe_ids = id_counts.index[dupe_mask]
dupe_ids = list(dupe_ids)

# %%
len(dupe_ids)
# Out:
# 313

# %%
list(dupe_ids[0:3])
# Out:
# ['3511ed92-c434', '8a6bbf3d-8a2d', 'a51dbaae-d88b']

# %%
df.loc[df['ID'].isin(dupe_ids[0:1]),:]
# Out:
#                  ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 5123  3511ed92-c434     180000    2          1         1   47     1     -2
# 5223  3511ed92-c434          0    0          0         0    0     0      0
#
#       PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 5123     -1     -1  ...          0          0          0         0      3312
# 5223      0      0  ...          0          0          0         0         0
#
#       PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 5123         0         0         0         0                           1
# 5223         0         0         0         0                           0
#
# [2 rows x 25 columns]

# %%
df_zero_mask = df == 0
#this returns true if all columns are true
feature_zero_mask = df_zero_mask.iloc[:,1:].all(axis=1)
sum(feature_zero_mask)
# Out:
# 315

# %%
df_clean_1 = df.loc[~feature_zero_mask].copy()

# %%
df_clean_1
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57    -1      0
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29995  ecff42d0-bdc6     220000    1          3         1   39     0      0
# 29996  99d1fa0e-222b     150000    1          3         2   43    -1     -1
# 29997  95cdd3e7-4f24      30000    1          2         2   37     4      3
# 29998  00d03f02-04cd      80000    1          3         1   41     1     -1
# 29999  15d69f9f-5ad3      50000    1          2         1   46     0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1     -1  ...          0          0          0         0       689
# 1          0      0  ...       3272       3455       3261         0      1000
# 2          0      0  ...      14331      14948      15549      1518      1500
# 3          0      0  ...      28314      28959      29547      2000      2019
# 4         -1      0  ...      20940      19146      19131      2000     36681
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29995      0      0  ...      88004      31237      15980      8500     20000
# 29996     -1     -1  ...       8979       5190          0      1837      3526
# 29997      2     -1  ...      20878      20582      19357         0         0
# 29998      0      0  ...      52774      11855      48944     85900      3409
# 29999      0      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [29685 rows x 25 columns]
